# %%
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_circles

# %%
X, y = make_circles(n_samples=1000, noise=0.1, random_state=0, factor=0.2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y == 0, 0], X[y == 0, 1], 'ob', alpha=0.5)
plt.plot(X[y == 1, 0], X[y == 1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title('Blue circles and red crosses')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# %%
model = Sequential()

# %%
model.add(Dense(4, input_shape = (2, ), activation = 'tanh'))

# %%
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 1000/1000 [==============================] - 0s - loss: 0.0385 - acc: 1.0000
# Epoch 2/20
# 1000/1000 [==============================] - 0s - loss: 0.0361 - acc: 1.0000
# Epoch 3/20
# 1000/1000 [==============================] - 0s - loss: 0.0342 - acc: 1.0000
# Epoch 4/20
# 1000/1000 [==============================] - 0s - loss: 0.0325 - acc: 1.0000
# Epoch 5/20
# 1000/1000 [==============================] - 0s - loss: 0.0309 - acc: 1.0000
# Epoch 6/20
# 1000/1000 [==============================] - 0s - loss: 0.0295 - acc: 1.0000
# Epoch 7/20
# 1000/1000 [==============================] - 0s - loss: 0.0281 - acc: 1.0000
# Epoch 8/20
# 1000/1000 [==============================] - 0s - loss: 0.0269 - acc: 1.0000
# Epoch 9/20
# 1000/1000 [==============================] - 0s - loss: 0.0257 - acc: 1.0000
# Epoch 10/20
# 1000/1000 [==============================] - 0s - loss: 0.0248 - acc: 1.0000
# Epoch 11/20
# 1000/1000 [==============================] - 0s - loss: 0.0239 - acc: 1.0000
# Epoch 12/20
# 1000/1000 [==============================] - 0s - loss: 0.0230 - acc: 1.0000
# Epoch 13/20
# 1000/1000 [==============================] - 0s - loss: 0.0222 - acc: 1.0000
# Epoch 14/20
# 1000/1000 [==============================] - 0s - loss: 0.0215 - acc: 1.0000
# Epoch 15/20
# 1000/1000 [==============================] - 0s - loss: 0.0208 - acc: 1.0000
# Epoch 16/20
# 1000/1000 [==============================] - 0s - loss: 0.0201 - acc: 1.0000
# Epoch 17/20
# 1000/1000 [==============================] - 0s - loss: 0.0195 - acc: 1.0000
# Epoch 18/20
# 1000/1000 [==============================] - 0s - loss: 0.0190 - acc: 1.0000
# Epoch 19/20
# 1000/1000 [==============================] - 0s - loss: 0.0185 - acc: 1.0000
# Epoch 20/20
# 1000/1000 [==============================] - 0s - loss: 0.0179 - acc: 1.0000

# %%
np.c_?

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
model.predict(np.array([[0.1, -0.1]]))
# Out:
# array([[ 0.99611181]], dtype=float32)

# %%
bb.ravel()
# Out:
# array([-1.5, -1.5, -1.5, ...,  1.5,  1.5,  1.5])

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha = 0.2)
plt.plot(X[y == 0, 0], X[y == 0, 1], 'ob', alpha=0.5)
plt.plot(X[y == 1, 0], X[y == 1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend('0')
plt.legend('1')
plt.title('Blue circles and red dots')

# %%
import tensorflow as tf

# %%
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
