# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix

# %%
data = pd.read_csv("../data/titanic-train.csv")

# %%
x = scatter_matrix(data.drop("PassengerId", axis = 1), figsize=(16,16))
